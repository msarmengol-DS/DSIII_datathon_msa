# %% [markdown]
# ## Notebook for showing the screenshots of the Power BI visualizations

# %%
from IPython.display import Image

# %% [markdown]
# ## SALES HISTORY

# %%
# SALES HISTORY
imagen_local = "Power BI/PowerBI -historico ventas.png"

# Show the image
Image(filename=imagen_local)

# %% [markdown]
# ## WEEKLY SEASONALITY

# %%
# weekly seasonality
imagen_local = "Power BI/PowerBI -estacionalidad.png"

# Show the image
Image(filename=imagen_local)

# %% [markdown]
# ## PREDICTION/ACTUAL SALES COMPARISON

# %%
#comparative sales/predictions
imagen_local = "Power BI/PowerBI -comparativa.png"

# Show the image
Image(filename=imagen_local)
